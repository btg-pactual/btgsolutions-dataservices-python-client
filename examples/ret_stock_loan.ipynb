# %%
from btgsolutions_dataservices import StockLoan
stock_loan = StockLoan(
    api_key='YOUR_API_KEY',
)

# %%
stock_loan.get_trades()

# %%
stock_loan.get_trades(
    ticker = 'PETR4'
)

# %%
stock_loan.get_paginated_trades(
    page = 1,
    limit = 1000
)

# %%
stock_loan.get_trades(
    page = 1,
    limit = 1000,
    ticker = 'PETR4'
)

# %%
stock_loan.get_available_tickers()
